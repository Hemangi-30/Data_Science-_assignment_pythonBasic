# %% [markdown]
# # Question 1 : Explain the key feature of python that make it a popular choice for programming
#
# ***Ans := ***
#
#
# Python is a dynamic, high-level, free open source, and interpreted programming language. It supports object-oriented programming as well as procedural-oriented programming.
#
# There are many key feature of python :
#
# **1. Free and Open Source**  :
#
# -> Python language is freely available at the official website and you can download it.
#
# -> Python Since it is open-source, this means that source code is also available to the public. So you can download it, use it as well as share it.
#
# **2. Easy to code** :
#
# -> Python is a high-level programming language.
#
# -> Python is very easy to learn the language as compared to other languages like C, C#, Javascript, Java, etc.
#
# -> It is very easy to code in the Python language and anybody can learn Python basics in a few hours or days.
#
# -> It is also a developer-friendly language.
#
#
# **3. Easy to Read** :
#
# -> Python’s syntax is really straightforward. The code block is defined by the indentations rather than by semicolons or brackets.
#
# **4. Object-Oriented Language**  :
#
# -> Python supports object-oriented language and concepts of classes, object encapsulation, etc.
#
# **5. Python is a Portable language**  :
#
# -> Python language is also a portable language. For example, if we have Python code for Windows and if we want to run this code on other platforms such as Linux, Unix, and Mac then we do not need to change it, we can run this code on any platform.
#
# **6. Python is an Integrated language**  :
#
# -> Python is also an Integrated language because we can easily integrate Python with other languages like C, C++, etc.
#
# **7. Interpreted Language: ** :
#
# -> Python is an Interpreted Language because Python code is executed line by line at a time. like other languages C, C++, Java, etc.
#
# -> there is no need to compile Python code this makes it easier to debug our code.
#
# ->The source code of Python is converted into an immediate form called bytecode.
#
#
# # Question 2 : Describe the role of predefined keywords in python and provide examples of how they are used in a program .
#
#
# **Keywords in Python** :=
#
# ->Python Keywords are some predefined and reserved words in Python that have special meanings.
#
# -> Keywords are used to define the syntax of the coding.
#
# ->The keyword cannot be used as an identifier, function, or variable name.
#
# -> All the keywords in Python are written in lowercase except True and False.
#
# **list of pyhton keyword :=**
#
# **1 . print keyword :**   to print the statement
#
# example:
#
# print("hello world !!!")
#
# ---
#
# 2.Type keyword : it returns the type of the given object
#
# Example :
#
# x = 10
# print(type(x))
#
# ---
#
# **3 . input keyword :=**   to take input from the user
#
#
# Example :
#
# name = input("What is your name? ")
#
# print("Hello, " + name + "!")
#
# ---
#
# so on , there are many built-in  keyword in python like
#
# Keywords
#
# Description
#
# -> and	:= This is a logical operator which returns true if both the operands are true else returns false.
#
# ->or	:= This is also a logical operator which returns true if anyone operand is true else returns false.
#
# ->not :=	This is again a logical operator it returns True if the operand is false else returns false.
#
# if,	elif	,else	,for	,while	,break	,as	,def	,lambda	,pass	,True	,False,try,
# with	,class,continue	,del	,except	,finally	,from	,global	,import	,in	,is,none	,nonlocal	,raise	,yield	,await
#
#
#
# #Question 3 : Compare and contrast mutable and immutable objects in Python with examples.
#
# **Mutable objects ** :=
#
# in Python are those that can be changed after they are created.
# --> like lists or dictionaries,set.
#
# **Immutable objects** :=
#
# on the other hand, cannot be changed after they are created.
# -> strings, integers, or tuples.
#
#
# # Question 4 :  Discuss the different types of operators in Python and provide examples of how they are used.
#
# -> operators are special symbols used to perform operations on variables and values.
#
# ->Python includes several types of operators, each serving different purposes.
#
# -> Here's an overview of the main types of operators with examples:
#
#
#                         **1. Arithmetic Operators := **
#
# These operators perform basic arithmetic operations.
#
# Example :
#
# a = 5
#
# b = 3
#
#
# -> Addition (+):
#
# result = a + b  # result is 8
#
# -> Subtraction (-):
#
# result = a - b  # result is 2
#
# -> Multiplication (*):
#
# result = a * b  # result is 15
#
# -> Division (/):
#
# result = a / b  # result is 1.6667 (float)
#
# -> Floor Division (//):
#
# result = a // b  # result is 1 (integer division)
#
# -> Modulus (%):
#
# result = a % b  # result is 2 (remainder)
#
# -> Exponentiation (**):
#
# result = a ** b  # result is 125 (5 raised to the power of 3)
#
#                         **2. Comparison Operators := **
#
# These operators compare values and return a boolean result.
#
# -> Equal to (==):
#
# result = (a == b)  # result is False
#
# -> Not equal to (!=):
#
# result = (a != b)  # result is True
#
# -> Greater than (>):
#
# result = (a > b)  # result is True
#
# -> Less than (<):
#
# result = (a < b)  # result is False
#
# -> Greater than or equal to (>=):
#
# result = (a >= b)  # result is True
#
# -> Less than or equal to (<=):
#
# result = (a <= b)  # result is False
#
#                       **3. Logical Operators := **
#
# These operators combine boolean expressions.
#
# ->And (and):
#
# result = (a > 2 and b < 5)  # result is True
#
# ->Or (or):
#
# result = (a > 2 or b > 5)  # result is True
#
# ->Not (not):
#
# result = not (a > 2)  # result is False
#
#
#                     **4. Assignment Operators : =**
# These operators are used to assign values to variables.
#
# Assignment (=):
#
# a = 10  # Assigns 10 to variable a
#
# Add and assign (+=):
#
# a += 5  # Equivalent to a = a + 5; a is now 15
#
# Subtract and assign (-=):
#
# a -= 3  # Equivalent to a = a - 3; a is now 12
#
# Multiply and assign (*=):
#
# a *= 2  # Equivalent to a = a * 2; a is now 24
#
# Divide and assign (/=):
#
# a /= 4  # Equivalent to a = a / 4; a is now 6.0
#
# Modulus and assign (%=):
#
# a %= 5  # Equivalent to a = a % 5; a is now 1
#
# Exponent and assign (**=):
#
#
# a **= 2  # Equivalent to a = a ** 2; a is now 1
#
# Floor divide and assign (//=):
#
# a //= 2  # Equivalent to a = a // 2; a is now 0
#
#                       **5. Bitwise Operators := **
# These operators perform bit-level operations.
#
# AND (&):
#
# a = 5  # 0101 in binary
# b = 3  # 0011 in binary
# result = a & b  # 0001 in binary, which is 1
#
# OR (|):
#
# result = a | b  # 0111 in binary, which is 7
#
# XOR (^):
#
# result = a ^ b  # 0110 in binary, which is 6
#
# NOT (~):
#
# result = ~a  # -6 (two's complement of 5)
#
# Left Shift (<<):
#
# result = a << 1  # 1010 in binary, which is 10
#
# Right Shift (>>):
#
# result = a >> 1  # 0010 in binary, which is 2
#
#                 **6. Membership Operators := **
#
# These operators test membership within sequences.
#
# In (in):
#
# fruits = ['apple', 'banana', 'cherry']
# result = 'banana' in fruits  # result is True
#
# Not in (not in):
#
# result = 'orange' not in fruits  # result is True
#
#
#                     **7. Identity Operators := **
#
# These operators compare the memory locations of two objects.
#
# Is (is):
#
# a = [1, 2, 3]
# b = a
# result = (a is b)  # result is True, since both refer to the same object
#
# Is not (is not):
#
# c = [1, 2, 3]
# result = (a is not c)  # result is True, since a and c are different objects

# %% [markdown]
# # Question : 5 explain the concept of type casting in Python with exampless
#
#
#
# -> Type casting in Python refers to converting a value from one data type to another.
#
# -> This is often necessary when performing operations that require a specific type or when you want to ensure that data is in the desired format.
#
# -> Python provides several built-in functions for type casting.
#
# -> Here’s a breakdown of how type casting works with examples:
#
# #**1. Integer to Float**
#
# When you need to convert an integer to a float, you can use the float() function.
#
# # Integer
# num = 5
# # Convert to float
# float_num = float(num)
#
# print(float_num)  # Output: 5.0
#
# #**2. Float to Integer**
#
#
# Converting a float to an integer is done using the int() function. Note that this conversion truncates the decimal part, it doesn’t round.
#
# # Float
# num = 5.7
#
# # Convert to integer
# int_num = int(num)
#
# print(int_num)  # Output: 5
#
# #**3. String to Integer**
#
#
# To convert a string that represents an integer to an actual integer, use the int() function.
#
# # String
# str_num = "123"
#
# # Convert to integer
# int_num = int(str_num)
#
# print(int_num)  # Output: 123
#
#
# #**4. String to Float**
#
# To convert a string that represents a floating-point number to a float, use the float() function.
#
# # String
# str_num = "123.45"
#
# # Convert to float
# float_num = float(str_num)
#
# print(float_num)  # Output: 123.45
#
# # **5. Integer to String**
#
# You can convert an integer to a string using the str() function.
#
# # Integer
# num = 123
#
# # Convert to string
# str_num = str(num)
#
# print(str_num)  # Output: '123'
#
# #**6. Float to String **
#
# To convert a float to a string, also use the str() function.
#
# # Float
# num = 123.45
#
# # Convert to string
# str_num = str(num)
#
# print(str_num)  # Output: '123.45'
#
# #**7. String to List or Tuple**
#
# When working with strings, you might want to convert them into lists or tuples. For example, you can split a string into a list using the split() method and then cast it to a tuple if needed.
#
# # String
# str_data = "apple,banana,cherry"
#
# # Convert to list
# list_data = str_data.split(',')
#
# print(list_data)  # Output: ['apple', 'banana', 'cherry']
#
# # Convert list to tuple
# tuple_data = tuple(list_data)
#
# print(tuple_data)  # Output: ('apple', 'banana', 'cherry')
#
# # **8. List to String**
#
# To convert a list to a string, you can use the join() method.
#
# # List
# list_data = ['apple', 'banana', 'cherry']
#
# # Convert to string
# str_data = ','.join(list_data)
#
# print(str_data)  # Output: 'apple,banana,cherry'
#
# # 9. Complex Type Casting
#
# Sometimes, you might need to perform more complex type conversions, such as converting a list of strings into a list of integers.
#
# # List of strings
# str_list = ['1', '2', '3']
#
# # Convert to list of integers
# int_list = [int(x) for x in str_list]
#
# print(int_list)  # Output: [1, 2, 3]
#
# # Summary
# Type casting is a crucial aspect of programming in Python, enabling you to ensure data is in the correct format for various operations. The primary functions used for type casting include:
#
# int(): Converts to integer.
# float(): Converts to float.
# str(): Converts to string.
# list(), tuple(), set(): Converts to corresponding data structures.

# %% [markdown]
# # Question : 6   How do conditional statements work in Python? Illustrate with examples.
#
#
# -> Conditional statements in Python allow you to execute different blocks of code based on certain conditions.
#
# -> These statements enable you to control the flow of execution in your programs.
#
# ->The main types of conditional statements in Python are if, elif, and else.
#
# -> Here’s a detailed look at how they work, with examples:
#
# # Basic if Statement
#
# The if statement evaluates a condition (an expression that returns True or False). If the condition is True, the block of code following the if statement is executed.
#
# Example :
#
#     x = 10
#     if x > 5:
#     print("x is greater than 5")
#
# Output:
#
# x is greater than 5
#
# #if-else Statement
#
# The if-else statement provides an alternative block of code to execute when the if condition is not met.
#
# Example :
#
#     x = 3
#     if x > 5:
#         print("x is greater than 5")
#     else:
#         print("x is not greater than 5")
#
# Output:
#
# x is not greater than 5
#
# #if-elif-else Statement
#
# The if-elif-else statement allows you to check multiple conditions. The elif (short for "else if") block provides additional conditions if the initial if condition is not met.
#
# Example :
# x = 7
#
#     if x > 10:
#         print("x is greater than 10")
#     elif x > 5:
#         print("x is greater than 5 but not greater than 10")
#     else:
#         print("x is 5 or less")
# Output:
#
# x is greater than 5 but not greater than 10
#
# # Nested if Statements
#
# You can nest if statements inside other if statements to handle more complex scenarios.
#
#
#     x = 10
#     y = 20
#
#     if x > 5:
#         if y > 15:
#             print("x is greater than 5 and y is greater than 15")
#         else:
#             print("x is greater than 5 but y is not greater than 15")
#     else:
#         print("x is not greater than 5")
# Output:
#
# x is greater than 5 and y is greater than 15
#
# # Combining Conditions
#
# You can combine multiple conditions using logical operators like and, or, and not.
#
#
#     x = 10
#     y = 5
#
#     if x > 0 and y > 0:
#         print("Both x and y are positive")
#
#     if not (x < 0):
#         print("x is non-negative")
# Output:
#
# Both x and y are positive
#
# x is non-negative
#
#
#
#
#
#
# # Question : 7   Describe the different types of loops in Python and their use cases with examples.
#
# --> loops are used to execute a block of code repeatedly based on certain conditions.
#
# -->Python supports several types of loops: for, while, and comprehensions. Each type of loop has its own use cases and syntax.
#
# --> Here's a detailed description of each type with examples:
#
#
# # 1. for Loop
#
# The for loop in Python is used to iterate over a sequence (like a list, tuple, string, or range) and execute a block of code for each item in the sequence. It’s particularly useful for iterating over collections of items.
#
# Basic Example
#
#
#     fruits = ["apple", "banana", "cherry"]
#
#     for fruit in fruits:
#         print(fruit)
#
# Output:
#
# banana
#
# cherry
#
#
#     # Using range to iterate 5 times
#     for i in range(5):
#         print(i)
# Output:
#
# 0
# 1
# 2
# 3
# 4
#     # Using enumerate to get index and value
#     for index, fruit in enumerate(fruits):
#         print(f"Index {index}: {fruit}")
# Output:
#
# Index 0: apple
#
# Index 1: banana
#
# Index 2: cherry
#
#
# # 2. while Loop
#
# The while loop repeatedly executes a block of code as long as a given condition is True. It’s useful when you don’t know in advance how many times you need to iterate.
#
# Basic Example
#
#     # Using a while loop to print numbers from 0 to 4
#     count = 0
#
#     while count < 5:
#         print(count)
#         count += 1
# Output:
#
# 0
# 1
# 2
# 3
# 4
#
#     # Using break to exit the loop
#     count = 0
#
#     while True:
#         if count == 3:
#             break
#         print(count)
#         count += 1
# Output:
#
# 0
# 1
# 2
#
#     # Using continue to skip an iteration
#     count = 0
#
#     while count < 5:
#         count += 1
#         if count == 3:
#             continue
#         print(count)
# Output:
#
# 1
# 2
# 4
# 5
#
# # 3. List Comprehensions
#
# List comprehensions provide a concise way to create lists. They are often used to perform operations on each item in a sequence and build a new list.
#
# Basic Example
#
#     # Creating a list of squares using a list comprehension
#     squares = [x**2 for x in range(5)]
#     print(squares)
# Output:
#
# [0, 1, 4, 9, 16]
#
#     # Creating a list of even numbers using a list comprehension
#     even_numbers = [x for x in range(10) if x % 2 == 0]
#     print(even_numbers)
# Output:
#
# [0, 2, 4, 6, 8]
#
#     # Creating a 2D matrix using nested list comprehensions
#     matrix = [[row * col for col in range(3)] for row in range(3)]
#     print(matrix)
# Output:
#
# [[0, 0, 0],
#
# [0, 1, 2],
#
#  [0, 2, 4]]
